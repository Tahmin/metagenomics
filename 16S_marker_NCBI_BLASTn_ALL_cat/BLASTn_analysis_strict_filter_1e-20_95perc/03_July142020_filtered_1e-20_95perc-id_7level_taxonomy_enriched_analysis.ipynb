# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('05_July142020_filtered_1e-20_95perc-id_subj_to_7level_taxonomy_enriched.csv')

# %%
df.head()
# Out:
#              subject  count  \
# 0  JAGRRH010000013.1  16532
# 1        NC_008588.1   5973
# 2         MN937452.1   5926
# 3        NC_014287.1   5916
# 4         MW645084.1   5905
#
#                                      7Level_Taxonomy  7Level_Lenght     Levels
# 0  Eukaryota; Sar; Stramenopiles; Ochrophyta; Bac...             10  10_Levels
# 1  Eukaryota; Sar; Stramenopiles; Ochrophyta; Bac...             10  10_Levels
# 2  Eukaryota; Sar; Stramenopiles; Ochrophyta; Bac...             10  10_Levels
# 3  Eukaryota; Sar; Alveolata; Dinophyceae; Peridi...              7   7_Levels
# 4  Eukaryota; Sar; Stramenopiles; Ochrophyta; Bac...             10  10_Levels

# %%
df['7Level_Taxonomy'] = df['7Level_Taxonomy'].str.split("; ")

# %%
df.head()
# Out:
#              subject  count  \
# 0  JAGRRH010000013.1  16532
# 1        NC_008588.1   5973
# 2         MN937452.1   5926
# 3        NC_014287.1   5916
# 4         MW645084.1   5905
#
#                                      7Level_Taxonomy  7Level_Lenght     Levels
# 0  [Eukaryota, Sar, Stramenopiles, Ochrophyta, Ba...             10  10_Levels
# 1  [Eukaryota, Sar, Stramenopiles, Ochrophyta, Ba...             10  10_Levels
# 2  [Eukaryota, Sar, Stramenopiles, Ochrophyta, Ba...             10  10_Levels
# 3  [Eukaryota, Sar, Alveolata, Dinophyceae, Perid...              7   7_Levels
# 4  [Eukaryota, Sar, Stramenopiles, Ochrophyta, Ba...             10  10_Levels

# %%
df[['Level_1','Level_2','Level_3','Level_4',
    'Level_5','Level_6','Level_7','Level_8',
    'Level_9','Level_10','Level_11']] = pd.DataFrame(df['7Level_Taxonomy'].tolist(), index = df.index)

# %%
df.head(10)
# Out:
#              subject  count  \
# 0  JAGRRH010000013.1  16532
# 1        NC_008588.1   5973
# 2         MN937452.1   5926
# 3        NC_014287.1   5916
# 4         MW645084.1   5905
# 5        NC_044463.1   5749
# 6        NC_044464.1   5735
# 7        NC_014267.1   5706
# 8         MK045450.1   5636
# 9         MH113811.1   5628
#
#                                      7Level_Taxonomy  7Level_Lenght  \
# 0  [Eukaryota, Sar, Stramenopiles, Ochrophyta, Ba...             10
# 1  [Eukaryota, Sar, Stramenopiles, Ochrophyta, Ba...             10
# 2  [Eukaryota, Sar, Stramenopiles, Ochrophyta, Ba...             10
# 3  [Eukaryota, Sar, Alveolata, Dinophyceae, Perid...              7
# 4  [Eukaryota, Sar, Stramenopiles, Ochrophyta, Ba...             10
# 5  [Eukaryota, Sar, Stramenopiles, Ochrophyta, Ba...             10
# 6  [Eukaryota, Sar, Stramenopiles, Ochrophyta, Ba...             10
# 7  [Eukaryota, Sar, Alveolata, Dinophyceae, Perid...              7
# ...

# %%
df.to_csv('06_July142020_filtered_1e-20_95perc-id_subj_to_7level_taxonomy_enriched_analysis.csv')

# %% [markdown]
# Now open file '06_July142020_filtered_1e-20_90perc-id_subj_to_7level_taxonomy_enriched_analysis.csv' in Excel & save as '07_July142020_filtered_1e-20_90perc-id_subj_to_7level_taxonomy_enriched_analysis.csv' and create 2 new columns & filter it according to the Phylum-phyta & Class-phyceae levels.
# √ Fill in the rest of the gaps for class & phylum levels by hand based on the '07_July142020_TaxonomyGuide_Hand-Corrected_By Schonna.csv'.

# %% [markdown]
# ### Visualization | Community Composition/Taxonomic distribution for July142020

# %%
df = pd.read_csv('07_July142020_filtered_1e-20_95perc-id_subj_to_7level_taxonomy_enriched_analysis.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0            subject  count  \
# 0           0  JAGRRH010000013.1  16532
# 1           1        NC_008588.1   5973
# 2           2         MN937452.1   5926
# 3           3        NC_014287.1   5916
# 4           4         MW645084.1   5905
#
#                                      7Level_Taxonomy  7Level_Lenght  \
# 0  ['Eukaryota', 'Sar', 'Stramenopiles', 'Ochroph...             10
# 1  ['Eukaryota', 'Sar', 'Stramenopiles', 'Ochroph...             10
# 2  ['Eukaryota', 'Sar', 'Stramenopiles', 'Ochroph...             10
# 3  ['Eukaryota', 'Sar', 'Alveolata', 'Dinophyceae...              7
# 4  ['Eukaryota', 'Sar', 'Stramenopiles', 'Ochroph...             10
#
#       Levels    Level_1 Level_2        Level_3      Level_4          Level_5  \
# 0  10_Levels  Eukaryota     Sar  Stramenopiles   Ochrophyta  Bacillariophyta
# 1  10_Levels  Eukaryota     Sar  Stramenopiles   Ochrophyta  Bacillariophyta
# ...

# %%
df.shape
# Out:
# (9092, 19)

# %%
df[['Phylum-phyta','Class-phyceae']].isna().sum()
# Out:
# Phylum-phyta     4941
# Class-phyceae    5495
# dtype: int64

# %%
plt.rcParams["figure.figsize"] = (30,8)
colors = sns.color_palette('pastel')[0:11]
df['Class-phyceae'].value_counts().plot.pie(labeldistance=1.15, 
                                     wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
                                     colors = colors,
                                     autopct='%1.1f%%',
                                     ylabel='')
# Out:
# <AxesSubplot:>

# %%
plt.rcParams["figure.figsize"] = (30,8)
colors = sns.color_palette('pastel')[0:11]
df['Class-phyceae'].value_counts()[1:10].plot.pie(labeldistance=1.15, 
                                     wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
                                     colors = colors,
                                     autopct='%1.1f%%',
                                     ylabel='')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16, 10))
colors = sns.color_palette('Paired')[0:55]
df['Class-phyceae'].value_counts()[1:101].plot.bar(color = colors, )
# Out:
# <AxesSubplot:>

# %%
plt.rcParams["figure.figsize"] = (30,8)
colors = sns.color_palette('pastel')[0:11]
df['Phylum-phyta'].value_counts().plot.pie(labeldistance=1.15, 
                                     wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
                                     colors = colors,
                                     autopct='%1.1f%%',
                                     ylabel='')
# Out:
# <AxesSubplot:>

# %%
plt.rcParams["figure.figsize"] = (30,8)
colors = sns.color_palette('pastel')[0:11]
df['Phylum-phyta'].value_counts()[1:5].plot.pie(labeldistance=1.15, 
                                     wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
                                     colors = colors,
                                     autopct='%1.1f%%',
                                     ylabel='')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16, 10))
colors = sns.color_palette('Paired')[0:55]
df['Phylum-phyta'].value_counts()[1:101].plot.bar(color = colors, )
# Out:
# <AxesSubplot:>
