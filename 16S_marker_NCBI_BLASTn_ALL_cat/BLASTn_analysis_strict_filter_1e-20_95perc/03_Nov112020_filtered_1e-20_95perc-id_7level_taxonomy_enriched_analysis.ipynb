# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('05_Nov112020_filtered_1e-20_95perc-id_subj_to_7level_taxonomy_enriched.csv')

# %%
df.head()
# Out:
#        subject  count                                    7Level_Taxonomy  \
# 0  NC_011600.1  44046  Eukaryota; Sar; Stramenopiles; Ochrophyta; PX ...
# 1   EU912438.1  43627  Eukaryota; Sar; Stramenopiles; Ochrophyta; PX ...
# 2  NC_053868.1  25846  Eukaryota; Sar; Stramenopiles; Stramenopiles i...
# 3   MT226925.1  25766  Eukaryota; Sar; Stramenopiles; Stramenopiles i...
# 4   MN121852.1  24049  Eukaryota; Sar; Stramenopiles; Ochrophyta; PX ...
#
#    7Level_Lenght    Levels
# 0              9  9_Levels
# 1              9  9_Levels
# 2              5  5_Levels
# 3              5  5_Levels
# 4              9  9_Levels

# %%
df['7Level_Taxonomy'] = df['7Level_Taxonomy'].str.split("; ")

# %%
df.head()
# Out:
#        subject  count                                    7Level_Taxonomy  \
# 0  NC_011600.1  44046  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 1   EU912438.1  43627  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 2  NC_053868.1  25846  [Eukaryota, Sar, Stramenopiles, Stramenopiles ...
# 3   MT226925.1  25766  [Eukaryota, Sar, Stramenopiles, Stramenopiles ...
# 4   MN121852.1  24049  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
#
#    7Level_Lenght    Levels
# 0              9  9_Levels
# 1              9  9_Levels
# 2              5  5_Levels
# 3              5  5_Levels
# 4              9  9_Levels

# %%
df[['Level_1','Level_2','Level_3','Level_4',
    'Level_5','Level_6','Level_7','Level_8',
    'Level_9','Level_10','Level_11']] = pd.DataFrame(df['7Level_Taxonomy'].tolist(), index = df.index)

# %%
df.head(10)
# Out:
#        subject  count                                    7Level_Taxonomy  \
# 0  NC_011600.1  44046  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 1   EU912438.1  43627  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 2  NC_053868.1  25846  [Eukaryota, Sar, Stramenopiles, Stramenopiles ...
# 3   MT226925.1  25766  [Eukaryota, Sar, Stramenopiles, Stramenopiles ...
# 4   MN121852.1  24049  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 5   MT800998.1  23304  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 6   KT188823.1  23253  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 7  NC_058274.1  22756  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 8   MW899036.1  22719  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 9  NC_049039.1  22561  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
#
#    7Level_Lenght    Levels    Level_1 Level_2        Level_3  \
# 0              9  9_Levels  Eukaryota     Sar  Stramenopiles
# 1              9  9_Levels  Eukaryota     Sar  Stramenopiles
# 2              5  5_Levels  Eukaryota     Sar  Stramenopiles
# 3              5  5_Levels  Eukaryota     Sar  Stramenopiles
# 4              9  9_Levels  Eukaryota     Sar  Stramenopiles
# 5              9  9_Levels  Eukaryota     Sar  Stramenopiles
# 6              9  9_Levels  Eukaryota     Sar  Stramenopiles
# 7              9  9_Levels  Eukaryota     Sar  Stramenopiles
# 8              9  9_Levels  Eukaryota     Sar  Stramenopiles
# 9              9  9_Levels  Eukaryota     Sar  Stramenopiles
#
#                         Level_4       Level_5        Level_6       Level_7  \
# 0                    Ochrophyta      PX clade  Xanthophyceae  Vaucheriales
# 1                    Ochrophyta      PX clade  Xanthophyceae  Vaucheriales
# 2  Stramenopiles incertae sedis  Schizocladia           None          None
# 3  Stramenopiles incertae sedis  Schizocladia           None          None
# 4                    Ochrophyta      PX clade   Phaeophyceae       Fucales
# 5                    Ochrophyta      PX clade   Phaeophyceae       Fucales
# 6                    Ochrophyta      PX clade   Phaeophyceae       Fucales
# 7                    Ochrophyta      PX clade   Phaeophyceae  Laminariales
# 8                    Ochrophyta      PX clade   Phaeophyceae  Laminariales
# 9                    Ochrophyta      PX clade   Phaeophyceae  Laminariales
#
#          Level_8      Level_9 Level_10 Level_11
# 0  Vaucheriaceae    Vaucheria     None     None
# 1  Vaucheriaceae    Vaucheria     None     None
# 2           None         None     None     None
# 3           None         None     None     None
# 4   Sargassaceae    Sargassum     None     None
# 5   Sargassaceae    Sargassum     None     None
# 6   Sargassaceae    Sargassum     None     None
# 7  Laminariaceae  Macrocystis     None     None
# 8  Laminariaceae  Macrocystis     None     None
# 9  Laminariaceae   Saccharina     None     None

# %%
df.to_csv('06_Nov112020_filtered_1e-20_95perc-id_subj_to_7level_taxonomy_enriched_analysis.csv')

# %% [markdown]
# Now open file '06_July142020_filtered_1e-20_90perc-id_subj_to_7level_taxonomy_enriched_analysis.csv' in Excel & save as '07_July142020_filtered_1e-20_90perc-id_subj_to_7level_taxonomy_enriched_analysis.csv' and create 2 new columns & filter it according to the Phylum-phyta & Class-phyceae levels.
# √ Fill in the rest of the gaps for class & phylum levels by hand based on the '07_July142020_TaxonomyGuide_Hand-Corrected_By Schonna.csv'.

# %% [markdown]
# ### Visualization | Community Composition/Taxonomic distribution for Nov112020

# %%
df = pd.read_csv('07_Nov112020_filtered_1e-20_95perc-id_subj_to_7level_taxonomy_enriched_analysis.csv')

# %%
df.shape
# Out:
# (9002, 19)

# %%
df[['Phylum-phyta','Class-phyceae']].isna().sum()
# Out:
# Phylum-phyta     4928
# Class-phyceae    5439
# dtype: int64

# %%
df.head(5)
# Out:
#    Unnamed: 0      subject  count  \
# 0           0  NC_011600.1  44046
# 1           1   EU912438.1  43627
# 2           2  NC_053868.1  25846
# 3           3   MT226925.1  25766
# 4           4   MN121852.1  24049
#
#                                      7Level_Taxonomy  7Level_Lenght    Levels  \
# 0  ['Eukaryota', 'Sar', 'Stramenopiles', 'Ochroph...              9  9_Levels
# 1  ['Eukaryota', 'Sar', 'Stramenopiles', 'Ochroph...              9  9_Levels
# 2  ['Eukaryota', 'Sar', 'Stramenopiles', 'Stramen...              5  5_Levels
# 3  ['Eukaryota', 'Sar', 'Stramenopiles', 'Stramen...              5  5_Levels
# 4  ['Eukaryota', 'Sar', 'Stramenopiles', 'Ochroph...              9  9_Levels
#
#      Level_1 Level_2        Level_3                       Level_4  \
# 0  Eukaryota     Sar  Stramenopiles                    Ochrophyta
# 1  Eukaryota     Sar  Stramenopiles                    Ochrophyta
# 2  Eukaryota     Sar  Stramenopiles  Stramenopiles incertae sedis
# 3  Eukaryota     Sar  Stramenopiles  Stramenopiles incertae sedis
# 4  Eukaryota     Sar  Stramenopiles                    Ochrophyta
#
#         Level_5        Level_6       Level_7        Level_8    Level_9  \
# 0      PX clade  Xanthophyceae  Vaucheriales  Vaucheriaceae  Vaucheria
# 1      PX clade  Xanthophyceae  Vaucheriales  Vaucheriaceae  Vaucheria
# 2  Schizocladia            NaN           NaN            NaN        NaN
# 3  Schizocladia            NaN           NaN            NaN        NaN
# 4      PX clade   Phaeophyceae       Fucales   Sargassaceae  Sargassum
#
#   Level_10 Level_11 Phylum-phyta  Class-phyceae
# 0      NaN      NaN   Ochrophyta  Xanthophyceae
# 1      NaN      NaN   Ochrophyta  Xanthophyceae
# 2      NaN      NaN          NaN            NaN
# 3      NaN      NaN          NaN            NaN
# 4      NaN      NaN   Ochrophyta   Phaeophyceae

# %%
plt.rcParams["figure.figsize"] = (30,8)
colors = sns.color_palette('pastel')[0:11]
df['Class-phyceae'].value_counts().plot.pie(labeldistance=1.15, 
                                     wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
                                     colors = colors,
                                     autopct='%1.1f%%',
                                     ylabel='')
# Out:
# <AxesSubplot:>

# %%
plt.rcParams["figure.figsize"] = (30,8)
colors = sns.color_palette('pastel')[0:11]
df['Class-phyceae'].value_counts()[0:10].plot.pie(labeldistance=1.15, 
                                     wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
                                     colors = colors,
                                     autopct='%1.1f%%',
                                     ylabel='')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16, 10))
colors = sns.color_palette('Paired')[0:55]
df['Class-phyceae'].value_counts()[1:101].plot.bar(color = colors, )
# Out:
# <AxesSubplot:>

# %%
plt.rcParams["figure.figsize"] = (30,8)
colors = sns.color_palette('pastel')[0:11]
df['Phylum-phyta'].value_counts().plot.pie(labeldistance=1.15, 
                                     wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
                                     colors = colors,
                                     autopct='%1.1f%%',
                                     ylabel='')
# Out:
# <AxesSubplot:>

# %%
plt.rcParams["figure.figsize"] = (30,8)
colors = sns.color_palette('pastel')[0:11]
df['Phylum-phyta'].value_counts()[0:5].plot.pie(labeldistance=1.15, 
                                     wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
                                     colors = colors,
                                     autopct='%1.1f%%',
                                     ylabel='')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16, 10))
colors = sns.color_palette('Paired')[0:55]
df['Phylum-phyta'].value_counts()[1:101].plot.bar(color = colors, )
# Out:
# <AxesSubplot:>
