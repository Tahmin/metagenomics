# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('05_July142020_filtered_1e-20_99perc-id_subj_to_7level_taxonomy_enriched.csv')

# %%
df.head()
# Out:
#              subject  count  \
# 0  JAGRRH010000013.1   3098
# 1        NC_014267.1   1131
# 2         MW645084.1   1120
# 3        NC_044463.1   1110
# 4        NC_014287.1   1109
#
#                                      7Level_Taxonomy  7Level_Lenght     Levels
# 0  Eukaryota; Sar; Stramenopiles; Ochrophyta; Bac...             10  10_Levels
# 1  Eukaryota; Sar; Alveolata; Dinophyceae; Peridi...              7   7_Levels
# 2  Eukaryota; Sar; Stramenopiles; Ochrophyta; Bac...             10  10_Levels
# 3  Eukaryota; Sar; Stramenopiles; Ochrophyta; Bac...             10  10_Levels
# 4  Eukaryota; Sar; Alveolata; Dinophyceae; Peridi...              7   7_Levels

# %%
df['7Level_Taxonomy'] = df['7Level_Taxonomy'].str.split("; ")

# %%
df.head()
# Out:
#              subject  count  \
# 0  JAGRRH010000013.1   3098
# 1        NC_014267.1   1131
# 2         MW645084.1   1120
# 3        NC_044463.1   1110
# 4        NC_014287.1   1109
#
#                                      7Level_Taxonomy  7Level_Lenght     Levels
# 0  [Eukaryota, Sar, Stramenopiles, Ochrophyta, Ba...             10  10_Levels
# 1  [Eukaryota, Sar, Alveolata, Dinophyceae, Perid...              7   7_Levels
# 2  [Eukaryota, Sar, Stramenopiles, Ochrophyta, Ba...             10  10_Levels
# 3  [Eukaryota, Sar, Stramenopiles, Ochrophyta, Ba...             10  10_Levels
# 4  [Eukaryota, Sar, Alveolata, Dinophyceae, Perid...              7   7_Levels

# %%
df[['Level_1','Level_2','Level_3','Level_4',
    'Level_5','Level_6','Level_7','Level_8',
    'Level_9','Level_10','Level_11']] = pd.DataFrame(df['7Level_Taxonomy'].tolist(), index = df.index)

# %%
df.head(10)
# Out:
#              subject  count  \
# 0  JAGRRH010000013.1   3098
# 1        NC_014267.1   1131
# 2         MW645084.1   1120
# 3        NC_044463.1   1110
# 4        NC_014287.1   1109
# 5         MT742551.1   1104
# 6         MK045450.1   1104
# 7        NC_044464.1   1098
# 8         MK045451.1   1092
# 9         MH113811.1   1088
#
#                                      7Level_Taxonomy  7Level_Lenght  \
# 0  [Eukaryota, Sar, Stramenopiles, Ochrophyta, Ba...             10
# 1  [Eukaryota, Sar, Alveolata, Dinophyceae, Perid...              7
# 2  [Eukaryota, Sar, Stramenopiles, Ochrophyta, Ba...             10
# 3  [Eukaryota, Sar, Stramenopiles, Ochrophyta, Ba...             10
# 4  [Eukaryota, Sar, Alveolata, Dinophyceae, Perid...              7
# 5  [Eukaryota, Sar, Stramenopiles, Ochrophyta, Ba...             11
# 6  [Eukaryota, Sar, Stramenopiles, Ochrophyta, Ba...             10
# 7  [Eukaryota, Sar, Stramenopiles, Ochrophyta, Ba...             10
# 8  [Eukaryota, Sar, Stramenopiles, Ochrophyta, Ba...             10
# 9  [Eukaryota, Sar, Stramenopiles, Ochrophyta, Ba...             10
#
#       Levels    Level_1 Level_2        Level_3      Level_4          Level_5  \
# 0  10_Levels  Eukaryota     Sar  Stramenopiles   Ochrophyta  Bacillariophyta
# 1   7_Levels  Eukaryota     Sar      Alveolata  Dinophyceae     Peridiniales
# 2  10_Levels  Eukaryota     Sar  Stramenopiles   Ochrophyta  Bacillariophyta
# 3  10_Levels  Eukaryota     Sar  Stramenopiles   Ochrophyta  Bacillariophyta
# 4   7_Levels  Eukaryota     Sar      Alveolata  Dinophyceae     Peridiniales
# 5  11_Levels  Eukaryota     Sar  Stramenopiles   Ochrophyta  Bacillariophyta
# 6  10_Levels  Eukaryota     Sar  Stramenopiles   Ochrophyta  Bacillariophyta
# 7  10_Levels  Eukaryota     Sar  Stramenopiles   Ochrophyta  Bacillariophyta
# 8  10_Levels  Eukaryota     Sar  Stramenopiles   Ochrophyta  Bacillariophyta
# 9  10_Levels  Eukaryota     Sar  Stramenopiles   Ochrophyta  Bacillariophyta
#
#                Level_6             Level_7        Level_8          Level_9  \
# 0    Bacillariophyceae  Bacillariophycidae  Bacillariales   Bacillariaceae
# 1  Kryptoperidiniaceae    Kryptoperidinium           None             None
# 2    Bacillariophyceae  Bacillariophycidae    Naviculales     Naviculaceae
# 3    Bacillariophyceae  Bacillariophycidae    Naviculales  Amphipleuraceae
# 4  Kryptoperidiniaceae           Durinskia           None             None
# 5    Bacillariophyceae  Bacillariophycidae  Bacillariales   Bacillariaceae
# 6    Bacillariophyceae  Bacillariophycidae    Naviculales  Amphipleuraceae
# 7    Bacillariophyceae  Bacillariophycidae    Naviculales  Amphipleuraceae
# 8    Bacillariophyceae  Bacillariophycidae    Naviculales  Amphipleuraceae
# 9    Bacillariophyceae  Bacillariophycidae  Bacillariales   Bacillariaceae
#
#      Level_10                Level_11
# 0   Nitzschia                    None
# 1        None                    None
# 2      Haslea                    None
# 3  Halamphora                    None
# 4        None                    None
# 5   Nitzschia  unclassified Nitzschia
# 6  Halamphora                    None
# 7  Halamphora                    None
# 8  Halamphora                    None
# 9   Nitzschia                    None

# %%
df.to_csv('06_July142020_filtered_1e-20_99perc-id_subj_to_7level_taxonomy_enriched_analysis.csv')

# %% [markdown]
# Now open file '06_July142020_filtered_1e-20_90perc-id_subj_to_7level_taxonomy_enriched_analysis.csv' in Excel & save as '07_July142020_filtered_1e-20_90perc-id_subj_to_7level_taxonomy_enriched_analysis.csv' and create 2 new columns & filter it according to the Phylum-phyta & Class-phyceae levels.
# √ Fill in the rest of the gaps for class & phylum levels by hand based on the '07_July142020_TaxonomyGuide_Hand-Corrected_By Schonna.csv'.

# %% [markdown]
# ### Visualization | Community Composition/Taxonomic distribution for July142020

# %%
df = pd.read_csv('07_July142020_filtered_1e-20_99perc-id_subj_to_7level_taxonomy_enriched_analysis.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0            subject  count  \
# 0           0  JAGRRH010000013.1   3098
# 1           1        NC_014267.1   1131
# 2           2         MW645084.1   1120
# 3           3        NC_044463.1   1110
# 4           4        NC_014287.1   1109
#
#                                      7Level_Taxonomy  7Level_Lenght  \
# 0  ['Eukaryota', 'Sar', 'Stramenopiles', 'Ochroph...             10
# 1  ['Eukaryota', 'Sar', 'Alveolata', 'Dinophyceae...              7
# 2  ['Eukaryota', 'Sar', 'Stramenopiles', 'Ochroph...             10
# 3  ['Eukaryota', 'Sar', 'Stramenopiles', 'Ochroph...             10
# 4  ['Eukaryota', 'Sar', 'Alveolata', 'Dinophyceae...              7
#
#       Levels    Level_1 Level_2        Level_3      Level_4          Level_5  \
# 0  10_Levels  Eukaryota     Sar  Stramenopiles   Ochrophyta  Bacillariophyta
# 1   7_Levels  Eukaryota     Sar      Alveolata  Dinophyceae     Peridiniales
# 2  10_Levels  Eukaryota     Sar  Stramenopiles   Ochrophyta  Bacillariophyta
# 3  10_Levels  Eukaryota     Sar  Stramenopiles   Ochrophyta  Bacillariophyta
# 4   7_Levels  Eukaryota     Sar      Alveolata  Dinophyceae     Peridiniales
#
#                Level_6             Level_7        Level_8          Level_9  \
# 0    Bacillariophyceae  Bacillariophycidae  Bacillariales   Bacillariaceae
# 1  Kryptoperidiniaceae    Kryptoperidinium            NaN              NaN
# 2    Bacillariophyceae  Bacillariophycidae    Naviculales     Naviculaceae
# 3    Bacillariophyceae  Bacillariophycidae    Naviculales  Amphipleuraceae
# 4  Kryptoperidiniaceae           Durinskia            NaN              NaN
#
#      Level_10 Level_11     Phylum-phyta      Class-phyceae
# 0   Nitzschia      NaN  Bacillariophyta  Bacillariophyceae
# 1         NaN      NaN              NaN        Dinophyceae
# 2      Haslea      NaN  Bacillariophyta  Bacillariophyceae
# 3  Halamphora      NaN  Bacillariophyta  Bacillariophyceae
# 4         NaN      NaN              NaN        Dinophyceae

# %%
df.shape
# Out:
# (6552, 19)

# %%
df[['Phylum-phyta','Class-phyceae']].isna().sum()
# Out:
# Phylum-phyta     3675
# Class-phyceae    4512
# dtype: int64

# %%
plt.rcParams["figure.figsize"] = (30,8)
colors = sns.color_palette('pastel')[0:11]
df['Class-phyceae'].value_counts().plot.pie(labeldistance=1.15, 
                                     wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
                                     colors = colors,
                                     autopct='%1.1f%%',
                                     ylabel='')
# Out:
# <AxesSubplot:>

# %%
plt.rcParams["figure.figsize"] = (30,8)
colors = sns.color_palette('pastel')[0:11]
df['Class-phyceae'].value_counts()[1:10].plot.pie(labeldistance=1.15, 
                                     wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
                                     colors = colors,
                                     autopct='%1.1f%%',
                                     ylabel='')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16, 10))
colors = sns.color_palette('Paired')[0:55]
df['Class-phyceae'].value_counts()[1:101].plot.bar(color = colors, )
# Out:
# <AxesSubplot:>

# %%
plt.rcParams["figure.figsize"] = (30,8)
colors = sns.color_palette('pastel')[0:11]
df['Phylum-phyta'].value_counts().plot.pie(labeldistance=1.15, 
                                     wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
                                     colors = colors,
                                     autopct='%1.1f%%',
                                     ylabel='')
# Out:
# <AxesSubplot:>

# %%
plt.rcParams["figure.figsize"] = (30,8)
colors = sns.color_palette('pastel')[0:11]
df['Phylum-phyta'].value_counts()[1:5].plot.pie(labeldistance=1.15, 
                                     wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
                                     colors = colors,
                                     autopct='%1.1f%%',
                                     ylabel='')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16, 10))
colors = sns.color_palette('Paired')[0:55]
df['Phylum-phyta'].value_counts()[1:101].plot.bar(color = colors, )
# Out:
# <AxesSubplot:>
