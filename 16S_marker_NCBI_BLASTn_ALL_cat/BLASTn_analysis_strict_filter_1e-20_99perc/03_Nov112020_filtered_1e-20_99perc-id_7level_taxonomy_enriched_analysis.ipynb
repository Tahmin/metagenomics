# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('05_Nov112020_filtered_1e-20_99perc-id_subj_to_7level_taxonomy_enriched.csv')

# %%
df.head()
# Out:
#        subject  count                                    7Level_Taxonomy  \
# 0  NC_046447.1   5087  Eukaryota; Sar; Stramenopiles; Ochrophyta; PX ...
# 1   MK107984.1   5085  Eukaryota; Sar; Stramenopiles; Ochrophyta; PX ...
# 2   MK107985.1   5085  Eukaryota; Sar; Stramenopiles; Ochrophyta; PX ...
# 3  NC_016735.1   5051  Eukaryota; Sar; Stramenopiles; Ochrophyta; PX ...
# 4   FM957154.1   5023  Eukaryota; Sar; Stramenopiles; Ochrophyta; PX ...
#
#    7Level_Lenght    Levels
# 0              9  9_Levels
# 1              9  9_Levels
# 2              9  9_Levels
# 3              9  9_Levels
# 4              9  9_Levels

# %%
df['7Level_Taxonomy'] = df['7Level_Taxonomy'].str.split("; ")

# %%
df.head()
# Out:
#        subject  count                                    7Level_Taxonomy  \
# 0  NC_046447.1   5087  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 1   MK107984.1   5085  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 2   MK107985.1   5085  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 3  NC_016735.1   5051  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 4   FM957154.1   5023  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
#
#    7Level_Lenght    Levels
# 0              9  9_Levels
# 1              9  9_Levels
# 2              9  9_Levels
# 3              9  9_Levels
# 4              9  9_Levels

# %%
df[['Level_1','Level_2','Level_3','Level_4',
    'Level_5','Level_6','Level_7','Level_8',
    'Level_9','Level_10','Level_11']] = pd.DataFrame(df['7Level_Taxonomy'].tolist(), index = df.index)

# %%
df.head(10)
# Out:
#        subject  count                                    7Level_Taxonomy  \
# 0  NC_046447.1   5087  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 1   MK107984.1   5085  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 2   MK107985.1   5085  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 3  NC_016735.1   5051  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 4   FM957154.1   5023  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 5  NC_029856.1   4989  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 6   MT795188.1   4987  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 7   MN265366.1   4987  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 8   MT795189.1   4987  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 9   MT800998.1   4986  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
#
#    7Level_Lenght    Levels    Level_1 Level_2        Level_3     Level_4  \
# 0              9  9_Levels  Eukaryota     Sar  Stramenopiles  Ochrophyta
# 1              9  9_Levels  Eukaryota     Sar  Stramenopiles  Ochrophyta
# 2              9  9_Levels  Eukaryota     Sar  Stramenopiles  Ochrophyta
# 3              9  9_Levels  Eukaryota     Sar  Stramenopiles  Ochrophyta
# 4              9  9_Levels  Eukaryota     Sar  Stramenopiles  Ochrophyta
# 5              9  9_Levels  Eukaryota     Sar  Stramenopiles  Ochrophyta
# 6              9  9_Levels  Eukaryota     Sar  Stramenopiles  Ochrophyta
# 7              9  9_Levels  Eukaryota     Sar  Stramenopiles  Ochrophyta
# 8              9  9_Levels  Eukaryota     Sar  Stramenopiles  Ochrophyta
# 9              9  9_Levels  Eukaryota     Sar  Stramenopiles  Ochrophyta
#
#     Level_5       Level_6       Level_7           Level_8      Level_9  \
# 0  PX clade  Phaeophyceae  Ectocarpales  Scytosiphonaceae  Scytosiphon
# 1  PX clade  Phaeophyceae  Ectocarpales  Scytosiphonaceae  Scytosiphon
# 2  PX clade  Phaeophyceae  Ectocarpales  Scytosiphonaceae  Scytosiphon
# 3  PX clade  Phaeophyceae       Fucales          Fucaceae        Fucus
# 4  PX clade  Phaeophyceae       Fucales          Fucaceae        Fucus
# 5  PX clade  Phaeophyceae       Fucales      Sargassaceae    Sargassum
# 6  PX clade  Phaeophyceae       Fucales      Sargassaceae    Sargassum
# 7  PX clade  Phaeophyceae       Fucales      Sargassaceae    Sargassum
# 8  PX clade  Phaeophyceae       Fucales      Sargassaceae    Sargassum
# 9  PX clade  Phaeophyceae       Fucales      Sargassaceae    Sargassum
#
#   Level_10 Level_11
# 0     None     None
# 1     None     None
# 2     None     None
# 3     None     None
# 4     None     None
# 5     None     None
# 6     None     None
# 7     None     None
# 8     None     None
# 9     None     None

# %%
df.to_csv('06_Nov112020_filtered_1e-20_99perc-id_subj_to_7level_taxonomy_enriched_analysis.csv')

# %% [markdown]
# Now open file '06_July142020_filtered_1e-20_90perc-id_subj_to_7level_taxonomy_enriched_analysis.csv' in Excel & save as '07_July142020_filtered_1e-20_90perc-id_subj_to_7level_taxonomy_enriched_analysis.csv' and create 2 new columns & filter it according to the Phylum-phyta & Class-phyceae levels.
# √ Fill in the rest of the gaps for class & phylum levels by hand based on the '07_July142020_TaxonomyGuide_Hand-Corrected_By Schonna.csv'.

# %% [markdown]
# ### Visualization | Community Composition/Taxonomic distribution for Nov112020

# %%
df = pd.read_csv('07_Nov112020_filtered_1e-20_99perc-id_subj_to_7level_taxonomy_enriched_analysis.csv')

# %%
df.shape
# Out:
# (6000, 19)

# %%
df[['Phylum-phyta','Class-phyceae']].isna().sum()
# Out:
# Phylum-phyta     3444
# Class-phyceae    3935
# dtype: int64

# %%
df.head(5)
# Out:
#    Unnamed: 0      subject  count  \
# 0           0  NC_046447.1   5087
# 1           1   MK107984.1   5085
# 2           2   MK107985.1   5085
# 3           3  NC_016735.1   5051
# 4           4   FM957154.1   5023
#
#                                      7Level_Taxonomy  7Level_Lenght    Levels  \
# 0  ['Eukaryota', 'Sar', 'Stramenopiles', 'Ochroph...              9  9_Levels
# 1  ['Eukaryota', 'Sar', 'Stramenopiles', 'Ochroph...              9  9_Levels
# 2  ['Eukaryota', 'Sar', 'Stramenopiles', 'Ochroph...              9  9_Levels
# 3  ['Eukaryota', 'Sar', 'Stramenopiles', 'Ochroph...              9  9_Levels
# 4  ['Eukaryota', 'Sar', 'Stramenopiles', 'Ochroph...              9  9_Levels
#
#      Level_1 Level_2        Level_3     Level_4   Level_5       Level_6  \
# 0  Eukaryota     Sar  Stramenopiles  Ochrophyta  PX clade  Phaeophyceae
# 1  Eukaryota     Sar  Stramenopiles  Ochrophyta  PX clade  Phaeophyceae
# 2  Eukaryota     Sar  Stramenopiles  Ochrophyta  PX clade  Phaeophyceae
# 3  Eukaryota     Sar  Stramenopiles  Ochrophyta  PX clade  Phaeophyceae
# 4  Eukaryota     Sar  Stramenopiles  Ochrophyta  PX clade  Phaeophyceae
#
#         Level_7           Level_8      Level_9 Level_10 Level_11 Phylum-phyta  \
# 0  Ectocarpales  Scytosiphonaceae  Scytosiphon      NaN      NaN   Ochrophyta
# 1  Ectocarpales  Scytosiphonaceae  Scytosiphon      NaN      NaN   Ochrophyta
# 2  Ectocarpales  Scytosiphonaceae  Scytosiphon      NaN      NaN   Ochrophyta
# 3       Fucales          Fucaceae        Fucus      NaN      NaN   Ochrophyta
# 4       Fucales          Fucaceae        Fucus      NaN      NaN   Ochrophyta
#
#   Class-phyceae
# 0  Phaeophyceae
# 1  Phaeophyceae
# 2  Phaeophyceae
# 3  Phaeophyceae
# 4  Phaeophyceae

# %%
plt.rcParams["figure.figsize"] = (30,8)
colors = sns.color_palette('pastel')[0:11]
df['Class-phyceae'].value_counts().plot.pie(labeldistance=1.15, 
                                     wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
                                     colors = colors,
                                     autopct='%1.1f%%',
                                     ylabel='')
# Out:
# <AxesSubplot:>

# %%
plt.rcParams["figure.figsize"] = (30,8)
colors = sns.color_palette('pastel')[0:11]
df['Class-phyceae'].value_counts()[1:10].plot.pie(labeldistance=1.15, 
                                     wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
                                     colors = colors,
                                     autopct='%1.1f%%',
                                     ylabel='')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16, 10))
colors = sns.color_palette('Paired')[0:55]
df['Class-phyceae'].value_counts()[1:101].plot.bar(color = colors, )
# Out:
# <AxesSubplot:>

# %%
plt.rcParams["figure.figsize"] = (30,8)
colors = sns.color_palette('pastel')[0:11]
df['Phylum-phyta'].value_counts().plot.pie(labeldistance=1.15, 
                                     wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
                                     colors = colors,
                                     autopct='%1.1f%%',
                                     ylabel='')
# Out:
# <AxesSubplot:>

# %%
plt.rcParams["figure.figsize"] = (30,8)
colors = sns.color_palette('pastel')[0:11]
df['Phylum-phyta'].value_counts()[1:5].plot.pie(labeldistance=1.15, 
                                     wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
                                     colors = colors,
                                     autopct='%1.1f%%',
                                     ylabel='')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16, 10))
colors = sns.color_palette('Paired')[0:55]
df['Phylum-phyta'].value_counts()[1:101].plot.bar(color = colors, )
# Out:
# <AxesSubplot:>
