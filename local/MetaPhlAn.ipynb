# %%
import pickle
import bz2

# %%
db = pickle.load(bz2.open('metaphlan_databases/mpa_v30_CHOCOPhlAn_201901.pkl', 'r'))

# %%
db
# Out:
# {'markers': {'244590__GeneID:2658371': {'ext': [],
#    'score': 0.0,
#    'clade': 's__Sulfolobus_spindle_shaped_virus_2',
#    'len': 147,
#    'taxon': 'k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Fuselloviridae|g__Alphafusellovirus|s__Sulfolobus_spindle_shaped_virus_2'},
#   '1054461__GeneID:11117646': {'ext': [],
#    'score': 0.0,
#    'clade': 't__Escherichia_phage_vB_EcoP_G7C',
#    'len': 114,
#    'taxon': 'k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Caudovirales|f__Podoviridae|g__G7cvirus|s__Escherichia_virus_G7C|t__Escherichia_phage_vB_EcoP_G7C'},
#   '1054461__GeneID:11117645': {'ext': ['PRJNA177527'],
#    'score': 1.0,
#    'clade': 't__Escherichia_phage_vB_EcoP_G7C',
#    'len': 315,
#    'taxon': 'k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Caudovirales|f__Podoviridae|g__G7cvirus|s__Escherichia_virus_G7C|t__Escherichia_phage_vB_EcoP_G7C'},
#   '205879__GeneID:1259969': {'ext': [],
# ...

# %%
db['taxonomy']['k__Bacteria|p__Proteobacteria|c__Alphaproteobacteria|o__Rhizobiales|f__Bradyrhizobiaceae|g__Bradyrhizobium|s__Bradyrhizobium_sp_LTSP849'] = ('2|1224|28211|356|41294|374|1615890',6365)
