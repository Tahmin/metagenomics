# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('05_db_blastn_Nov112020_filtered_1e-20_subj_to_7level_taxonomy_enriched.csv')

# %%
df.head()
# Out:
#        subject   count                                    7Level_Taxonomy  \
# 0  NC_011600.1  150242  Eukaryota; Sar; Stramenopiles; Ochrophyta; PX ...
# 1   EU912438.1  148386  Eukaryota; Sar; Stramenopiles; Ochrophyta; PX ...
# 2  NC_046005.1  108333  Eukaryota; Sar; Stramenopiles; Ochrophyta; PX ...
# 3   MG739403.1  107667  Eukaryota; Sar; Stramenopiles; Ochrophyta; PX ...
# 4  NC_053868.1  106131  Eukaryota; Sar; Stramenopiles; Stramenopiles i...
#
#    7Level_Lenght    Levels
# 0              9  9_Levels
# 1              9  9_Levels
# 2              9  9_Levels
# 3              9  9_Levels
# 4              5  5_Levels

# %%
df['7Level_Taxonomy'] = df['7Level_Taxonomy'].str.split("; ")

# %%
df.head()
# Out:
#        subject   count                                    7Level_Taxonomy  \
# 0  NC_011600.1  150242  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 1   EU912438.1  148386  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 2  NC_046005.1  108333  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 3   MG739403.1  107667  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 4  NC_053868.1  106131  [Eukaryota, Sar, Stramenopiles, Stramenopiles ...
#
#    7Level_Lenght    Levels
# 0              9  9_Levels
# 1              9  9_Levels
# 2              9  9_Levels
# 3              9  9_Levels
# 4              5  5_Levels

# %%
df[['Level_1','Level_2','Level_3','Level_4',
    'Level_5','Level_6','Level_7','Level_8',
    'Level_9','Level_10','Level_11']] = pd.DataFrame(df['7Level_Taxonomy'].tolist(), index = df.index)

# %%
df.head(10)
# Out:
#        subject   count                                    7Level_Taxonomy  \
# 0  NC_011600.1  150242  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 1   EU912438.1  148386  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 2  NC_046005.1  108333  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 3   MG739403.1  107667  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 4  NC_053868.1  106131  [Eukaryota, Sar, Stramenopiles, Stramenopiles ...
# 5   MT226925.1  105751  [Eukaryota, Sar, Stramenopiles, Stramenopiles ...
# 6  NC_057231.1  105063  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 7   MT732096.1  104739  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 8  NC_044689.1  104570  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
# 9  NC_018523.1  104569  [Eukaryota, Sar, Stramenopiles, Ochrophyta, PX...
#
#    7Level_Lenght    Levels    Level_1 Level_2        Level_3  \
# 0              9  9_Levels  Eukaryota     Sar  Stramenopiles
# 1              9  9_Levels  Eukaryota     Sar  Stramenopiles
# 2              9  9_Levels  Eukaryota     Sar  Stramenopiles
# 3              9  9_Levels  Eukaryota     Sar  Stramenopiles
# 4              5  5_Levels  Eukaryota     Sar  Stramenopiles
# 5              5  5_Levels  Eukaryota     Sar  Stramenopiles
# 6              9  9_Levels  Eukaryota     Sar  Stramenopiles
# 7              9  9_Levels  Eukaryota     Sar  Stramenopiles
# 8              9  9_Levels  Eukaryota     Sar  Stramenopiles
# 9              9  9_Levels  Eukaryota     Sar  Stramenopiles
#
#                         Level_4       Level_5        Level_6       Level_7  \
# 0                    Ochrophyta      PX clade  Xanthophyceae  Vaucheriales
# 1                    Ochrophyta      PX clade  Xanthophyceae  Vaucheriales
# 2                    Ochrophyta      PX clade   Phaeophyceae  Ectocarpales
# 3                    Ochrophyta      PX clade   Phaeophyceae  Ectocarpales
# 4  Stramenopiles incertae sedis  Schizocladia           None          None
# 5  Stramenopiles incertae sedis  Schizocladia           None          None
# 6                    Ochrophyta      PX clade   Phaeophyceae  Laminariales
# 7                    Ochrophyta      PX clade   Phaeophyceae  Laminariales
# 8                    Ochrophyta      PX clade   Phaeophyceae  Laminariales
# 9                    Ochrophyta      PX clade   Phaeophyceae  Laminariales
#
#          Level_8      Level_9 Level_10 Level_11
# 0  Vaucheriaceae    Vaucheria     None     None
# 1  Vaucheriaceae    Vaucheria     None     None
# 2  Chordariaceae  Cladosiphon     None     None
# 3  Chordariaceae  Cladosiphon     None     None
# 4           None         None     None     None
# 5           None         None     None     None
# 6  Laminariaceae    Laminaria     None     None
# 7  Laminariaceae    Laminaria     None     None
# 8  Laminariaceae    Laminaria     None     None
# 9  Laminariaceae   Saccharina     None     None

# %%
df.to_csv('06_Nov112020_filtered_1e-20_subj_to_7level_taxonomy_enriched_analysis.csv')

# %% [raw]
# Now open 06-...csv file in Excel to filter and sort it to 2 new columns: "Phylum-phyta"	& "Class-phyceae" levels.

# %%
df = pd.read_csv('07_Nov112020_filtered_1e-20_subj_to_7level_taxonomy_enriched_analysis.csv')

# %%
df.shape
# Out:
# (9883, 19)

# %%
df[['Phylum-phyta','Class-phyceae']].isna().sum()
# Out:
# Phylum-phyta     4337
# Class-phyceae    5043
# dtype: int64

# %%
df.head(5)
# Out:
#    Unnamed: 0      subject   count  \
# 0           0  NC_011600.1  150242
# 1           1   EU912438.1  148386
# 2           2  NC_046005.1  108333
# 3           3   MG739403.1  107667
# 4           4  NC_053868.1  106131
#
#                                      7Level_Taxonomy  7Level_Lenght    Levels  \
# 0  ['Eukaryota', 'Sar', 'Stramenopiles', 'Ochroph...              9  9_Levels
# 1  ['Eukaryota', 'Sar', 'Stramenopiles', 'Ochroph...              9  9_Levels
# 2  ['Eukaryota', 'Sar', 'Stramenopiles', 'Ochroph...              9  9_Levels
# 3  ['Eukaryota', 'Sar', 'Stramenopiles', 'Ochroph...              9  9_Levels
# 4  ['Eukaryota', 'Sar', 'Stramenopiles', 'Stramen...              5  5_Levels
#
#      Level_1 Level_2        Level_3                       Level_4  \
# 0  Eukaryota     Sar  Stramenopiles                    Ochrophyta
# 1  Eukaryota     Sar  Stramenopiles                    Ochrophyta
# 2  Eukaryota     Sar  Stramenopiles                    Ochrophyta
# 3  Eukaryota     Sar  Stramenopiles                    Ochrophyta
# 4  Eukaryota     Sar  Stramenopiles  Stramenopiles incertae sedis
#
#         Level_5        Level_6       Level_7        Level_8      Level_9  \
# 0      PX clade  Xanthophyceae  Vaucheriales  Vaucheriaceae    Vaucheria
# 1      PX clade  Xanthophyceae  Vaucheriales  Vaucheriaceae    Vaucheria
# 2      PX clade   Phaeophyceae  Ectocarpales  Chordariaceae  Cladosiphon
# 3      PX clade   Phaeophyceae  Ectocarpales  Chordariaceae  Cladosiphon
# 4  Schizocladia            NaN           NaN            NaN          NaN
#
#   Level_10 Level_11 Phylum-phyta  Class-phyceae
# 0      NaN      NaN   Ochrophyta  Xanthophyceae
# 1      NaN      NaN   Ochrophyta  Xanthophyceae
# 2      NaN      NaN   Ochrophyta   Phaeophyceae
# 3      NaN      NaN   Ochrophyta   Phaeophyceae
# 4      NaN      NaN          NaN            NaN

# %%
plt.rcParams["figure.figsize"] = (30,8)
colors = sns.color_palette('pastel')[0:11]
df['Class-phyceae'].value_counts().plot.pie(labeldistance=1.15, 
                                     wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
                                     colors = colors,
                                     autopct='%1.1f%%',
                                     ylabel='')
# Out:
# <AxesSubplot:>

# %%
plt.rcParams["figure.figsize"] = (30,8)
colors = sns.color_palette('pastel')[0:11]
df['Class-phyceae'].value_counts()[1:101].plot.pie(labeldistance=1.15, 
                                     wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
                                     colors = colors,
                                     autopct='%1.1f%%',
                                     ylabel='')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16, 10))
colors = sns.color_palette('Paired')[0:55]
df['Class-phyceae'].value_counts()[1:101].plot.bar(color = colors, )
# Out:
# <AxesSubplot:>

# %%
plt.rcParams["figure.figsize"] = (30,8)
colors = sns.color_palette('pastel')[0:11]
df['Phylum-phyta'].value_counts().plot.pie(labeldistance=1.15, 
                                     wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
                                     colors = colors,
                                     autopct='%1.1f%%',
                                     ylabel='')
# Out:
# <AxesSubplot:>

# %%
plt.rcParams["figure.figsize"] = (30,8)
colors = sns.color_palette('pastel')[0:11]
df['Phylum-phyta'].value_counts()[1:101].plot.pie(labeldistance=1.15, 
                                     wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
                                     colors = colors,
                                     autopct='%1.1f%%',
                                     ylabel='')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16, 10))
colors = sns.color_palette('Paired')[0:55]
df['Phylum-phyta'].value_counts()[1:101].plot.bar(color = colors, )
# Out:
# <AxesSubplot:>
